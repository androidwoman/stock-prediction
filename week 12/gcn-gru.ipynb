# %%
# !git clone https://github.com/troyyxk/gcgru_stock_prediction.git
# Out:
# Cloning into 'gcgru_stock_prediction'...
# remote: Enumerating objects: 240, done.
# remote: Total 240 (delta 0), reused 0 (delta 0), pack-reused 240
# Receiving objects: 100% (240/240), 51.04 MiB | 20.48 MiB/s, done.
# Resolving deltas: 100% (136/136), done.
# Updating files: 100% (172/172), done.

# %%
# %cd gcgru_stock_prediction/
# Out:
# /content/gcgru_stock_prediction

# %%
# !pip install --upgrade tensorflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 87.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 3.0.5
#     Uninstalling keras-3.0.5:
#       Successfully uninstalled keras-3.0.5
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ...

# %%
# !python3 train.py
# Out:
# 2024-03-04 09:31:52.330801: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-04 09:31:52.330857: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-04 09:31:52.333003: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-04 09:31:52.343379: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
